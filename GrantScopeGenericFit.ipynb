# %% [markdown]
# ## Upload your API output text file to the environment or place it in the same folder where this notebook is. Alternatively you will need to update the path in the second code cell.

# %%
# Run to load imports
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Change the name of the file in data = '' and then run all the cells.

# %%
# Read the first few lines of the newly uploaded file to understand its structure

data = 'EpiPrgSupport.txt'
with open(data, 'r') as file:
    data_lines = [file.readline().strip() for _ in range(5)]

data_lines

# %% [markdown]
# # If all looks good, clear the previous output, then run the next cell. This will load the data into a dataframe, show your columns and a data sample, and tell you how many results are in the file.

# %%
# Read the entire file and parsing it as JSON
with open(data, 'r') as file:
    data_content = file.read()

# Parse the JSON content
data_json = json.loads(data_content)

# Extract the grant details from the "rows" key
grants_data = data_json["data"]["rows"]

# Convert to a pandas DataFrame
df = pd.DataFrame(grants_data)

# Set Pandas display options to show all columns
pd.set_option('display.max_columns', None)

# Display the first 5 rows
print("First 5 rows:")
display(df.head())

# Display all the column headers
print("List of Column headers:")
display(df.columns.tolist())

# Display the count of the rows
total_results = len(df)
print(f"Total number of API CALL results: {total_results}")
# Out:
# First 5 rows:
#   funder_key                                 funder_profile_url  \
# 0    GATE023  https://fconline.foundationcenter.org/fdo-gran...
# 1    GATE023  https://fconline.foundationcenter.org/fdo-gran...
# 2    JOHN015  https://fconline.foundationcenter.org/fdo-gran...
# 3    JOHN015  https://fconline.foundationcenter.org/fdo-gran...
# 4    MISS071  https://fconline.foundationcenter.org/fdo-gran...
#
#                           funder_name funder_city funder_state funder_country  \
# 0     BILL & MELINDA GATES FOUNDATION     Seattle           WA  United States
# 1     BILL & MELINDA GATES FOUNDATION     Seattle           WA  United States
# 2  The Robert Wood Johnson Foundation   Princeton           NJ  United States
# 3  The Robert Wood Johnson Foundation   Princeton           NJ  United States
# 4      MISSOURI FOUNDATION FOR HEALTH    St Louis           MO  United States
#
#                funder_type funder_zipcode funder_country_code  funder_ein  \
# 0       Family foundations     98109-4636             6252001  56-2618866
# 1       Family foundations     98109-4636             6252001  56-2618866
# 2  Independent foundations     08540-6614             6252001  22-6029397
# 3  Independent foundations     08540-6614             6252001  22-6029397
# 4         Public charities     63110-3840             6252001  43-1880952
#
#   funder_gs_profile_update_level    recip_key  \
# 0                    Silver 2021       902117
# 1                    Silver 2021  CEI15046957
# 2                           None      5639080
# 3                           None       932616
# 4                      Gold 2023      5103586
#
#                                           recip_name    recip_city  \
# 0                University of Washington Foundation       Seattle
# 1           The Rostropovich-Vishnevskaya Foundation          None
# 2  Temple University-Of the Commonwealth System o...  Philadelphia
# 3                                  Temple University  Philadelphia
# 4                              WASHINGTON UNIVERSITY      St Louis
#
#   recip_state  recip_country recip_zipcode recip_country_code   recip_ein  \
# 0          WA  United States    98195-0001            6252001  51-0193884
# 1          WA  United States          None            6252001        None
# 2          PA  United States    19122-6096            6252001        None
# 3          PA  United States     191226094            6252001  23-1365971
# 4          MO  United States    63112-1408            6252001  43-0653611
#
#   recip_organization_code    recip_organization_tran  \
# 0                EA040000           Public charities
# 1                    None                       None
# 2                EA040000           Public charities
# 3      EA040000; EF000000  Public charities; Schools
# 4                EA040000           Public charities
#
#                           recip_gs_profile_link recip_gs_profile_update_level  \
# 0  https://www.guidestar.org/Profile/51-0193884                          None
# 1                                          None                          None
# 2                                          None                          None
# 3  https://www.guidestar.org/Profile/23-1365971                          None
# 4  https://www.guidestar.org/Profile/43-0653611                          None
#
#                    grant_key  amount_usd  \
# 0  hgrant-transaction-267683    424695.0
# 1  hgrant-transaction-275489    299865.0
# 2                   49564377    982712.0
# 3  hgrant-transaction-225411    982712.0
# 4    egrant-transaction-6304    356615.0
#
#                                   grant_subject_code  \
# 0   SE150801; SE130300; ST000000; SE030000; SB000000
# 1             SE130100; SE130300; ST040000; SE151000
# 2             SE130300; SE020000; SJ040000; SR040200
# 3             SR040200; SE130300; SE020000; SJ040000
# 4  SE150801; SE130500; SE130300; SE050800; SE1301...
#
#                                   grant_subject_tran grant_population_code  \
# 0  HIV/AIDS; Epidemiology; International relation...                  None
# 1  Communicable disease control; Epidemiology; In...                  None
# 2  Epidemiology; Health care access; Legal servic...              PE000000
# 3  Ethnic and racial minority rights; Epidemiolog...              PE000000
# 4  HIV/AIDS; Sexually transmitted disease control...              PH020100
#
#       grant_population_tran                     grant_strategy_code  \
# 0                      None                  UM0100; UN0000; UM0200
# 1                      None                          UM0100; UN0000
# 2  Ethnic and racial groups  UD0000; UJ0000; UK0000; UN0000; UM0100
# 3  Ethnic and racial groups  UK0000; UM0100; UJ0000; UN0000; UD0000
# 4      People with HIV/AIDS                          UK0100; UN0000
#
#                                  grant_strategy_tran grant_transaction_code  \
# 0     Research; Program support; Program evaluations                   TA00
# 1                          Research; Program support                   TA00
# 2  Capacity-building and technical assistance; Ne...                   TA00
# 3  Policy, advocacy and systems reform; Research;...                   TA00
# 4                          Advocacy; Program support                   TA00
#
#   grant_transaction_tran grant_geo_area_code grant_geo_area_tran year_issued  \
# 0            Cash grants             6255146                            2023
# 1            Cash grants             6255147                            2023
# 2            Cash grants             6252001       United States        2022
# 3            Cash grants             6252001       United States        2022
# 4            Cash grants             4407066           St. Louis        2022
#
#   grant_duration                                  grant_description  \
# 0           None  to evaluate the public health impact of using ...
# 1           None  To enhance Rotavirus disease surveillance in a...
# 2          24.00  To (1) support public health practitioners, at...
# 3          24.00  To (1) support public health practitioners, at...
# 4          30.00  The project goal is to improve HIV testing coo...
#
#               last_updated
# 0  2023-07-28 16:30:52.000
# 1  2023-07-28 16:31:37.000
# 2  2022-02-11 01:00:00.000
# 3  2023-07-28 16:31:40.000
# 4  2023-06-22 02:10:22.000
# List of Column headers:
# ['funder_key',
#  'funder_profile_url',
#  'funder_name',
#  'funder_city',
#  'funder_state',
#  'funder_country',
#  'funder_type',
#  'funder_zipcode',
#  'funder_country_code',
#  'funder_ein',
#  'funder_gs_profile_update_level',
#  'recip_key',
#  'recip_name',
#  'recip_city',
#  'recip_state',
#  'recip_country',
#  'recip_zipcode',
#  'recip_country_code',
#  'recip_ein',
#  'recip_organization_code',
#  'recip_organization_tran',
#  'recip_gs_profile_link',
#  'recip_gs_profile_update_level',
#  'grant_key',
#  'amount_usd',
#  'grant_subject_code',
#  'grant_subject_tran',
#  'grant_population_code',
#  'grant_population_tran',
#  'grant_strategy_code',
#  'grant_strategy_tran',
#  'grant_transaction_code',
#  'grant_transaction_tran',
#  'grant_geo_area_code',
#  'grant_geo_area_tran',
#  'year_issued',
#  'grant_duration',
#  'grant_description',
#  'last_updated']
# Total number of API CALL results: 25

# %%
# Identify the top 10 funders by total grant amount for grants
top_funders = df.groupby('funder_name')['amount_usd'].sum().nlargest(10)

# Plot the top 10 funders
top_funders_plot = top_funders.plot(kind='barh', figsize=(10, 6), color='skyblue')
plt.title('Top 10 Funders for Grants')
plt.xlabel('Total Amount (USD)')
plt.ylabel('Funder Name')
plt.gca().invert_yaxis()  # Inverting the y-axis to display the largest value at the top
plt.show()

# %%
import matplotlib.pyplot as plt
import json
import pandas as pd

# Read the content of the new data file
with open(data, 'r') as file:
    data_content_new = file.read()
data_json_new = json.loads(data_content_new)

# Extract the grant details from the "rows" key
grants_data_new = data_json_new["data"]["rows"]

# Convert to a pandas DataFrame
df_new = pd.DataFrame(grants_data_new)

# Strip leading and trailing spaces from the 'grant_subject_tran' values
df_new['grant_subject_tran'] = df_new['grant_subject_tran'].apply(lambda subjects: [subject.strip() for subject in str(subjects).split(';')] if subjects else [])

# Use the 'explode' method to create separate rows for each unique subject
df_exploded_subjects_new = df_new.explode('grant_subject_tran')

# Grab the top 10 grant subjects by count
top_subjects_new = df_exploded_subjects_new['grant_subject_tran'].value_counts().nlargest(10)

import matplotlib.pyplot as plt

# Plot the top 10 grant subjects
top_subjects_plot_new = top_subjects_new.plot(kind='barh', figsize=(10, 6), color='lightgreen')
plt.title('Top 10 Grant Subjects for Grants')
plt.xlabel('Number of Grants')
plt.ylabel('Subject')
plt.gca().invert_yaxis()  # Inverting the y-axis to display the largest value at the top
plt.show()

# %%
# Split the 'grant_population_tran' column by semicolons and stripping spaces
df['grant_population_tran'] = df['grant_population_tran'].apply(lambda x: [item.strip() for item in str(x).split(';')] if x else [])

# Use the 'explode' method to create separate rows for each unique target population
df_exploded_populations = df.explode('grant_population_tran')

# Analyze the top 10 target populations by count
top_populations = df_exploded_populations['grant_population_tran'].value_counts().nlargest(10)

# Plot the top 10 target populations
top_populations_plot = top_populations.plot(kind='barh', figsize=(10, 6), color='lightcoral')
plt.title('Top 10 Target Populations for Grants')
plt.xlabel('Number of Grants')
plt.ylabel('Target Population')
plt.gca().invert_yaxis()  # Inverting the y-axis to display the largest value at the top
plt.show()

# %%
# Group by state and summing the grant amounts
health_admin_state_distribution = df.groupby('recip_state')['amount_usd'].sum().nlargest(10)

# Plotting the distribution across states
health_admin_state_distribution_plot = health_admin_state_distribution.plot(kind='barh', figsize=(10, 6), color='gold')
plt.title('Top 10 States by Grant Amount for Grants')
plt.xlabel('Total Amount (USD)')
plt.ylabel('State')
plt.gca().invert_yaxis()  # Inverting the y-axis to display the largest value at the top
plt.show()

# %%
import plotly.express as px

# Read the entire file and parsing it as JSON
with open(data, 'r') as file:  # Update the file path as needed
    data_content = file.read()

# Parse the JSON content
data_json = json.loads(data_content)

# Extract the grant details from the "rows" key
grants_data = data_json["data"]["rows"]

# Convert to a pandas DataFrame
grants_df = pd.DataFrame(grants_data)

# Split the 'grant_subject_tran' and 'grant_population_tran' columns by semicolons and stripping spaces
grants_df['grant_subject_tran'] = grants_df['grant_subject_tran'].apply(lambda x: [item.strip() for item in str(x).split(';')] if x else [])
grants_df['grant_population_tran'] = grants_df['grant_population_tran'].apply(lambda x: [item.strip() for item in str(x).split(';')] if x else [])

# Use the 'explode' method to create separate rows for each unique subject and population
df_exploded_subjects_populations = grants_df.explode('grant_subject_tran').explode('grant_population_tran')

# Create a pivot table for heatmap
pivot_table_subjects_populations = pd.pivot_table(df_exploded_subjects_populations, values='amount_usd', index='grant_subject_tran', columns='grant_population_tran', aggfunc='sum')

# Make an interactive heatmap using Plotly Express
fig_heatmap = px.imshow(pivot_table_subjects_populations, title='Grants by Subject and Target Population')
# Update the layout to make the heatmap larger
fig_heatmap.update_layout(width=800, height=600)
fig_heatmap.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="26e35de1-19d1-4378-8ce9-7c567742819b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26e35de1-19d1-4378-8ce9-7c567742819b")) {                    Plotly.newPlot(                        "26e35de1-19d1-4378-8ce9-7c567742819b",                        [{"coloraxis":"coloraxis","name":"0","x":["Academics","Adults","American Indians","Caregivers","Children and youth","Economically disadvantaged people","Ethnic and racial groups","Families","Gay men","Health","Indigenous peoples","Older adults","People of African descent","People of Latin American descent","People with HIV\u002fAIDS","People with diseases and illnesses","Religious groups","Researchers","Seniors","Social and economic status","Students","Teachers","Widows and widowers","Women and girls"],"y":["Cancers","Cardiology","Communicable disease control","Community health care","Community mental health care","Convalescent care","Data management software","Dermatology","Diagnostic imaging","Diseases and conditions","E-health","Endocrine, nutritional and metabolic diseases","Epidemiology","Ethnic and racial minority rights","Eye diseases","Geriatrics","Graduate and professional education","HIV\u002fAIDS","Health","Health care access","Health care administration and financing","Health care clinics","Health care quality","Heart and circulatory system diseases","Holistic medicine","Human services information","Immunology","In-patient medical care","Infant care","Internal medicine","International development","Legal services","Mental and behavioral disorders","Molecular biology","Occupational health","Oncology","Ophthalmology","Orthopedics","Patients' rights","Pediatrics","Pharmacies","Pharmacology","Physical fitness","Preventive care","Psychiatry","Public affairs","Respiratory system diseases","School-based health care","Science","Senior assisted living","Sexually transmitted disease control","Skin conditions","Special population support","Traditional medicine and healing","Urgent care","Vision care"],"z":[[null,10000.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,10000.0],[null,null,null,16500.0,null,16500.0,45000.0,16500.0,null,45000.0,null,16500.0,null,null,null,null,16500.0,45000.0,16500.0,45000.0,45000.0,45000.0,16500.0,null],[null,7420.0,null,null,7420.0,null,null,null,4500000.0,null,7420.0,null,7420.0,7420.0,4856615.0,null,null,null,null,null,null,null,null,null],[null,null,null,16500.0,null,16500.0,null,16500.0,null,null,null,16500.0,null,null,null,null,16500.0,null,16500.0,null,null,null,16500.0,null],[null,null,null,null,null,null,45000.0,null,null,45000.0,null,null,null,null,null,null,null,45000.0,null,45000.0,45000.0,45000.0,null,null],[null,null,null,16500.0,null,16500.0,null,16500.0,null,null,null,16500.0,null,null,null,null,16500.0,null,16500.0,null,null,null,16500.0,null],[4395154.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,16500.0,null,16500.0,null,16500.0,null,null,null,16500.0,null,null,null,null,16500.0,null,16500.0,null,null,null,16500.0,null],[null,null,null,null,null,null,45000.0,null,null,45000.0,null,null,null,null,null,null,null,45000.0,null,45000.0,45000.0,45000.0,null,null],[null,10000.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,10000.0],[null,null,null,null,null,null,45000.0,null,null,45000.0,null,null,null,null,null,null,null,45000.0,null,45000.0,45000.0,45000.0,null,null],[null,null,null,null,null,null,45000.0,null,null,45000.0,null,null,null,null,null,null,null,45000.0,null,45000.0,45000.0,45000.0,null,null],[4845154.0,17420.0,50000 ...

# %%
import plotly.express as px

# Use the 'explode' method to create separate rows for each unique subject
df_exploded_subjects = grants_df.explode('grant_subject_tran')

# Make an interactive scatter plot using Plotly Express, with subject on the x-axis, amount on the y-axis, and awarder as color
fig_scatter = px.scatter(df_exploded_subjects, x='grant_subject_tran', y='amount_usd', color='funder_name', title='Grants by Subject and Awarder')
fig_scatter.update_layout(width=800, height=600)
fig_scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6a91813c-adbf-4d70-b3de-a6f13433102e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a91813c-adbf-4d70-b3de-a6f13433102e")) {                    Plotly.newPlot(                        "6a91813c-adbf-4d70-b3de-a6f13433102e",                        [{"hovertemplate":"funder_name=BILL & MELINDA GATES FOUNDATION\u003cbr\u003egrant_subject_tran=%{x}\u003cbr\u003eamount_usd=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BILL & MELINDA GATES FOUNDATION","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"BILL & MELINDA GATES FOUNDATION","orientation":"v","showlegend":true,"x":["HIV\u002fAIDS","Epidemiology","International relations","Health care administration and financing","Education","Communicable disease control","Epidemiology","International development","Infectious and parasitic diseases","HIV\u002fAIDS","Communicable disease control","Molecular biology","Sexually transmitted disease control","Pharmacology","Human services information","Epidemiology","Patients' rights","Skin conditions","Special population support","International development","Social sciences","Disasters and emergency management","Epidemiology","International relations","HIV\u002fAIDS","Epidemiology","International development"],"xaxis":"x","y":[424695.0,424695.0,424695.0,424695.0,424695.0,299865.0,299865.0,299865.0,299865.0,4500000.0,4500000.0,4500000.0,4500000.0,4500000.0,4500000.0,4500000.0,4500000.0,4500000.0,4500000.0,4500000.0,800003.0,800003.0,800003.0,800003.0,584711.0,584711.0,584711.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"funder_name=The Robert Wood Johnson Foundation\u003cbr\u003egrant_subject_tran=%{x}\u003cbr\u003eamount_usd=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"The Robert Wood Johnson Foundation","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"The Robert Wood Johnson Foundation","orientation":"v","showlegend":true,"x":["Epidemiology","Health care access","Legal services","Ethnic and racial minority rights","Ethnic and racial minority rights","Epidemiology","Health care access","Legal services"],"xaxis":"x","y":[982712.0,982712.0,982712.0,982712.0,982712.0,982712.0,982712.0,982712.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"funder_name=MISSOURI FOUNDATION FOR HEALTH\u003cbr\u003egrant_subject_tran=%{x}\u003cbr\u003eamount_usd=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MISSOURI FOUNDATION FOR HEALTH","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"MISSOURI FOUNDATION FOR HEALTH","orientation":"v","showlegend":true,"x":["HIV\u002fAIDS","Sexually transmitted disease control","Epidemiology","Preventive care","Communicable disease control","Health care administration and financing","In-patient medical care"],"xaxis":"x","y":[356615.0,356615.0,356615.0,356615.0,356615.0,356615.0,356615.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"funder_name=Fish & Wildlife Foundation of Florida, Inc.\u003cbr\u003egrant_subject_tran=%{x}\u003cbr\u003eamount_usd=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fish & Wildlife Foundation of Florida, Inc.","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Fish & Wildlife Foundation of Florida, Inc.","orientation":"v","showlegend":true,"x":["Epidemiology","Biodiversity","Epidemiology","Biodiversity"],"xaxis":"x","y":[68000.0,68000.0,46000.0,46000.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"funder_name=Community Foundation of Greater Memphis\u003cbr\u003egrant_subject_tran=%{x}\u003cbr\u003eamount_usd=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Community Foundation of Greater Memphis","marker":{"color":"#FFA15A"," ...

# %%
import plotly.express as px

# Calculate the sum of grant amounts by subject
subject_amounts = df_exploded_subjects_populations.groupby('grant_subject_tran')['amount_usd'].sum().reset_index()

# Threshold to determine smaller categories
threshold = subject_amounts['amount_usd'].quantile(0.75)  # You can adjust this value

# Aggregate smaller categories into "Other"
subject_amounts['subject'] = subject_amounts.apply(lambda row: row['grant_subject_tran'] if row['amount_usd'] > threshold else 'Other', axis=1)
subject_amounts_aggregated = subject_amounts.groupby('subject')['amount_usd'].sum().reset_index()

# Make an interactive pie chart using Plotly Express
fig_pie = px.pie(subject_amounts_aggregated, values='amount_usd', names='subject', title='Distribution of Grants by Subject')
fig_pie.update_layout(width=800, height=600)
fig_pie.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="64c7cf67-f418-474e-bf86-a7aba292fbbe" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64c7cf67-f418-474e-bf86-a7aba292fbbe")) {                    Plotly.newPlot(                        "64c7cf67-f418-474e-bf86-a7aba292fbbe",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"subject=%{label}\u003cbr\u003eamount_usd=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Communicable disease control","Data management software","Epidemiology","Ethnic and racial minority rights","HIV\u002fAIDS","Health care access","Human services information","International development","International relations","Legal services","Molecular biology","Other","Patients' rights","Pharmacology","Sexually transmitted disease control","Skin conditions","Special population support"],"legendgroup":"","name":"","showlegend":true,"values":[9693580.0,4395154.0,23650421.0,1965424.0,10366021.0,2350924.0,9270000.0,9884576.0,1224698.0,1965424.0,9000000.0,13104606.0,9000000.0,9270000.0,9356615.0,9000000.0,9000000.0],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords" ...
